# %% [markdown]
# # Question 1: Basic Input & Output

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print("Hello", name + ", you are", age, "years old.")
# Out:
# Hello zafran, you are 22 years old.

# %% [markdown]
# # Question 2: Even or Odd Checker

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print(" Even ")
else:
    print(" Odd ")
# Out:
#  Even

# %% [markdown]
# # Question 3: Simple List Program

# %%
numbers = [10, 20, 30, 40, 50]

print(numbers)

print(sum(numbers))
# Out:
# [10, 20, 30, 40, 50]
# 150
