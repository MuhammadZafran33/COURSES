# %% [markdown]
# ## Arithmetic Operation

# %%
friends = 0
friends  = friends  + 1 #Addition Operator
#friends  +=1 #Augmented Sign Operator
friends  = friends  + friends
print(friends)
# Out:
# 1

# %%
x = 9.9
y = -3
z= 9
result= round(x)
result1 = abs(y)
result2 = pow(4,3)
result3 = max(x,y,z)
result4 = min(x,y,z)


print(result)
print(result1)
print(result2)
print(result3)
print(result4)
# Out:
# 10
# 3
# 64
# 9.9
# -3

# %%
import math
print(math.pi)
result7 = math.sqrt(z)
print(result7)
# Out:
# 3.141592653589793
# 3.0

# %%
# Ceil func used to round floating point up... 
result = math.ceil(x)
print(result)
resultfloor = math.floor(x)
print(resultfloor)
# Out:
# 10
# 9

# %% [markdown]
# ##### Circumference of circle...

# %%
# Circumference............
import math
radius = float(input("enter the Radius: "))
circumference= 2*math.pi *radius
print(f"the Circumference of a Circle with Radius {radius} is {round(circumference,2)}cm ")
# Out:
# the Circumference of a Circle with Radius 3.0 is 18.85cm

# %% [markdown]
# ##### Area of a circle..

# %%
import math
radius = float(input("enter the Radius: "))
area = math.pi * pow(radius, 2)

print(f"The Area of the circle is: {round(area,2)}cm")
# Out:
# The Area of the circle is: 50.27cm

# %% [markdown]
# ##### Hypotenous of right angle...

# %%
import math
a = float(input("Enter side A: "))
b = float(input("Enter side B: "))

c = math.sqrt(pow(a,2) + pow(b,2))

print(f"Side C = {round(c,3)}")
# Out:
# Side C = 6.403
