# %%
age = int(input("Enter your age: "))
print(f"Happy BirthDay {name} you become {age} years nld")
# Out:
# Happy BirthDay zafran you become 20 years nld

# %%
name = str(input("Enter your Roll Number: "))
print(f"Hallo {name}")
# Out:
# Hallo zafran

# %%
age = str(age)
print(type(age))
# Out:
# <class 'str'>

# %%
length = float(input("Enter the Length: "))
Width = float(input("Enter the Width: "))
print(f" The area of Rectangle is {area}cm")
area = length * Width
# Out:
#  The area of Rectangle is 400.0cm

# %%
item = input("What item would you like to buy?: ")
price = float(input("What is the price of that item?: "))
quantity = int(input("Enter quantity of that item?: "))
total = price*quantity
print(f"You have bought {quantity} x {item}/s items ")
print(f"Your total is: pkr {total}")
# Out:
# You have bought 500000 x Gold/s items
# Your total is: pkr 2000000.0

# %% [markdown]
# # Madlib Game...........

# %%
adjective1 = input("Enter a adjective (description): ")
noun1  = input("Enter a noun(Person), place, or thing ")
adjective2 = input("Enter a adjective (description): ")
verb1 = input("Enter a verb ending with 'ing' ")
adjective3 = input("Enter a adjective (description): ")


print(f"Today i went to a {adjective1} zoo.")
print(f"In an exhibit, I saw a {noun1} ")
print(f"{noun1} was {adjective2} and {verb1}")
print(f"I was  {adjective3}!")
# Out:
# Today i went to a Buddy zoo.
# In an exhibit, I saw a Elon
# Elon was Angry and screeching
# I was  Happy!
