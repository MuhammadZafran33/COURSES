# %%
principle = 0
rate = 0
time = 0
while principle <=0:
    principle = float(input("Enter the principal amount: "))
    if principle <= 0:
        print("Principle cannot be less then zero or negative")



while  rate<=0:
    rate = float(input("Enter the intereset rate: "))
    if rate <= 0:
        print("intereset rate cannot be less then zero or negative")



while  time<=0:
    time = float(input("Enter the Time in Years: "))
    if time <= 0:
        print("intereset rate cannot be less then zero or negative")
# print(principle)
# print(rate)
# print(time)

total = principle * pow((1+rate/100), time)
print(f"Balance after {time} year/s: ${total:.2f}")
# Out:
# Balance after 3.0 year/s: $1520.87

# %% [markdown]
# #### 2nd Method...

# %%
principle = 0
rate = 0
time = 0
while True:
    principle = float(input("Enter the principal amount: "))
    if principle < 0:
        print("Principle cannot be less then zero or negative")
    else:
        break


while  True:
    rate = float(input("Enter the intereset rate: "))
    if rate < 0:
        print("intereset rate cannot be less then zero or negative")
    else:
        break


while  True:
    time = float(input("Enter the Time in Years: "))
    if time < 0:
        print("intereset rate cannot be less then zero or negative")
    else:
        break

# print(principle)
# print(rate)
# print(time)

total = principle * pow((1+rate/100), time)
print(f"Balance after {time} year/s: ${total:.2f}")
# Out:
# Balance after 3.0 year/s: $1000.00
